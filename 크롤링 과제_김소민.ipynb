# %%
import selenium 
import sys
import pandas as pd #csv를 읽고 dataframe을 사용하기 위한 pandas
from selenium import webdriver #브라우저를 띄우고 컨트롤하기 위한 webdriver
from selenium.webdriver.common.keys import Keys #브라우저에 키입력 용
from selenium.webdriver.common.by import By #webdriver를 이용해 태그를 찾기 위함
from selenium.webdriver.support.ui import WebDriverWait #Explicitly wait을 위함
from webdriver_manager.chrome import ChromeDriverManager #크롬에서 크롤링 진행 크롬 웹 드라이버 설치시 필요
from selenium.webdriver.support import expected_conditions as EC #브라우저에 특정 요소 상태 확인을 위해
from bs4 import BeautifulSoup #브라우저 태그를 가져오고 파싱하기 위함
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException,TimeoutException 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time
import re
import csv
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
options = Options()
options.binary_location = "C:/Program Files/Google/Chrome/Application/chrome.exe"
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get('https://www.musinsa.com/app/codimap/lists?style_type=&tag_no=&brand=&display_cnt=60&list_kind=big&sort=comment_cnt&page=1')
category=[]
title=[]
date=[]
view=[]
comment_num=[]

for i in range(1,61):
    ca=f'/html/body/div[3]/div[3]/form/div[4]/div/ul/li[{i}]/div[2]/a/span'
    ti=f'/html/body/div[3]/div[3]/form/div[4]/div/ul/li[{i}]/div[2]/a/strong'
    da=f'/html/body/div[3]/div[3]/form/div[4]/div/ul/li[{i}]/div[3]/span[1]'
    vi=f'/html/body/div[3]/div[3]/form/div[4]/div/ul/li[{i}]/div[3]/span[2]'
    co=f'/html/body/div[3]/div[3]/form/div[4]/div/ul/li[{i}]/div[3]/span[3]'
    cat=driver.find_element(By.XPATH,ca).text
    tit=driver.find_element(By.XPATH,ti).text
    dat=driver.find_element(By.XPATH,da).text
    vie=driver.find_element(By.XPATH,vi).text
    com=driver.find_element(By.XPATH,co).text
    print(cat,tit,dat,vie,com)
    category.append(cat)
    title.append(tit)
    date.append(dat)
    view.append(vie.replace('조회',''))
    comment_num.append(com.replace('댓글',''))
# Out:
# 캐주얼 톤온톤 코디 21.07.02 조회 16,085 댓글 49
# 캐주얼 블랙 매니아 21.02.23 조회 34,675 댓글 46
# 캐주얼 오늘의 코디 22.03.22 조회 12,201 댓글 38
# 댄디 추천 댄디 룩 21.09.15 조회 20,187 댓글 27
# 캐주얼 릴랙스 룩 21.02.23 조회 23,539 댓글 22
# 스트릿 힙하다 힙해 21.02.03 조회 35,289 댓글 21
# 캐주얼 심플한 코디 21.07.30 조회 39,584 댓글 18
# 댄디 데이트 코디 21.12.24 조회 10,312 댓글 18
# 댄디 훈훈 남친 룩 21.03.24 조회 19,346 댓글 16
# 캐주얼 지금 입기 좋아 21.08.31 조회 20,215 댓글 16
# 댄디 서머 데이트 룩 21.07.26 조회 7,859 댓글 15
# 댄디 남친 룩으로 제격 21.12.24 조회 9,650 댓글 14
# 포멀 깔끔하게 즐겨 21.11.09 조회 6,312 댓글 13
# 아메리칸 캐주얼 남다른 감각 21.11.17 조회 4,335 댓글 11
# 캐주얼 편안함의 완성 21.10.04 조회 19,423 댓글 11
# 캐주얼 원 마일 웨어 21.10.08 조회 16,782 댓글 10
# 아메리칸 캐주얼 아메리칸 캐주얼 21.12.21 조회 4,493 댓글 10
# 캐주얼 편하게 완성 21.07.21 조회 14,981 댓글 10
# 캐주얼 레이어드의 매력 21.06.04 조회 12,672 댓글 9
# 포멀 매력적인 포멀 룩 21.09.17 조회 11,336 댓글 9
# 댄디 레이어드의 매력 21.11.23 조회 10,162 댓글 8
# 캐주얼 발랄함 가득! 21.07.05 조회 3,138 댓글 8
# 댄디 남친 룩의 정석 20.11.04 조회 16,268 댓글 8
# 포멀 손색 없는 단정함 21.11.12 조회 3,157 댓글 8
# 시크 시크한 감각 21.08.20 조회 3,715 댓글 8
# 캐주얼 서머 캠퍼스 룩 22.07.19 조회 3,135 댓글 8
# ...

# %%
column=['codimap_category', 'codimap_title', 'codimap_date', 'views', 'comment_numbers'] 
resultframe=pd.DataFrame(zip(category,title,date,view,comment_num), columns=column) 
display(resultframe)
# Out:
#    codimap_category codimap_title codimap_date    views comment_numbers
# 0               캐주얼        톤온톤 코디     21.07.02   16,085              49
# 1               캐주얼        블랙 매니아     21.02.23   34,675              46
# 2               캐주얼        오늘의 코디     22.03.22   12,201              38
# 3                댄디       추천 댄디 룩     21.09.15   20,187              27
# 4               캐주얼         릴랙스 룩     21.02.23   23,539              22
# 5               스트릿        힙하다 힙해     21.02.03   35,289              21
# 6               캐주얼        심플한 코디     21.07.30   39,584              18
# 7                댄디        데이트 코디     21.12.24   10,312              18
# 8                댄디       훈훈 남친 룩     21.03.24   19,346              16
# 9               캐주얼      지금 입기 좋아     21.08.31   20,215              16
# 10               댄디      서머 데이트 룩     21.07.26    7,859              15
# 11               댄디     남친 룩으로 제격     21.12.24    9,650              14
# ...

# %%
output_path = "C:\\Users\\user\\Desktop\\Ybigta_교육세션\\크롤링 과제.csv"
resultframe.to_csv(output_path, encoding='utf-8-sig')
